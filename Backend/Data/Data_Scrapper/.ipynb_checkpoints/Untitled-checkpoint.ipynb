# %%
data = [
    [1, 3047, "Attendant Operator (Chemical Plant)", 4, "10+2 with Science Subjects or equivalent", "Engineering", "2 years"],
    [2, 3031, "Draftsman (Mechanical)", 4, "Engineering", "Engineering", "2 years"],
    [3, 3115, "Electrician", 4, "Engineering", "Engineering", "2 years"],
    [4, 3063, "Electronic Mechanic", 4, "Engineering", "Engineering", "2 years"],
    [5, 3032, "Fitter", 4, "Engineering", "Engineering", "2 years"],
    [6, 3033, "Foundryman", 3, "10th pass", "Engineering", "1 year"],
    [7, 3090, "Information and Communication Technology System Maintenance", 4, "10+2 with Science Subjects or equivalent", "Engineering", "2 years"],
    [8, 3065, "Instrument Mechanic", 4, "Engineering", "Engineering", "2 years"],
    [9, 3048, "Instrument Mechanic (Chemical Plant)", 4, "Engineering", "Engineering", "2 years"],
    [10, 3057, "Interior Design and Decoration", 3, "Engineering", "Engineering", "1 year"],
    [11, 3049, "Laboratory Assistant (Chemical Plant)", 4, "Engineering", "Engineering", "2 years"],
    [12, 3035, "Machinist", 4, "Engineering", "Engineering", "2 years"],
    [13, 3036, "Machinist (Grinder)", 4, "Engineering", "Engineering", "2 years"],
    [14, 3050, "Maintenance Mechanic (Chemical Plant)", 4, "Engineering", "Engineering", "2 years"],
    [15, 3026, "Marine Fitter", 4, "Engineering", "Engineering", "2 years"],
    [16, 3017, "Mechanic Tractor", 3, "Engineering", "Engineering", "1 year"],
    [17, 3015, "Mechanic Diesel", 3, "Engineering", "Engineering", "1 year"],
    [18, 3016, "Mechanic Motor Vehicle", 4, "Engineering", "Engineering", "2 years"],
    [19, 3067, "Refrigeration and Air Conditioning Technician", 4, "Engineering", "Engineering", "2 years"],
    [20, 3051, "Plastic Processing Operator", 3, "10+2 with Science Subjects or equivalent", "Engineering", "1 year"],
    [21, 3060, "Surveyor", 4, "Engineering", "Engineering", "2 years"],
    [22, 3039, "Tool and Die Maker (Press Tools, Jigs, and Fixtures)", 4, "Engineering", "Engineering", "2 years"],
    [23, 3040, "Turner", 4, "Engineering", "Engineering", "2 years"],
    [24, 3020, "Cosmetology", 3, "10+2 with Science Subjects or equivalent", "Non-Engineering", "1 year"],
    [25, 3094, "Computer Operator and Programming Assistant (COPA)", 3, "Non-Engineering", "Non-Engineering", "1 year"],
    [26, 3097, "Desktop Publishing Operator", 3, "Non-Engineering", "Non-Engineering", "1 year"],
    [27, 3055, "Draftsman (Civil)", 4, "10+2 with Science Subjects or equivalent", "Engineering", "2 years"],
    [28, 3007, "Dress Making", 3, "10+2 or 8th pass", "Non-Engineering", "1 year"],
    [29, 3008, "Fashion Designing and Technology", 3, "10+2 or 10th pass", "Non-Engineering", "1 year"],
    [30, 3085, "Health Sanitary Inspector", 3, "Non-Engineering", "Non-Engineering", "1 year"],
    [31, 3114, "Plumber", 3, "10+2 or 8th pass", "Engineering", "1 year"],
    [32, 3009, "Sewing Technology", 3, "Non-Engineering", "Non-Engineering", "1 year"],
    [33, 3103, "Stenographer Secretarial Assistant (English)", 3, "10+2 or 10th pass", "Non-Engineering", "1 year"],
    [34, 3126, "Surface Ornamentation Techniques (Embroidery)", 3, "10+2 or 8th pass", "Non-Engineering", "1 year"],
    [35, 3059, "Painter General", 4, "Engineering", "Engineering", "2 years"],
    [36, 3037, "Sheet Metal Worker", 3, "Engineering", "Engineering", "1 year"],
    [37, 3041, "Welder", 3, "Engineering", "Engineering", "1 year"],
    [38, 3116, "Wireman", 4, "Engineering", "Engineering", "2 years"],
    [39, 3086, "Physiotherapy Technician", 3, "10+2 or 10th pass", "Non-Engineering", "1 year"],
    [40, 3093, "Computer Hardware and Networking Maintenance", 3, "10+2 or 10th pass (with Science subjects)", "Non-Engineering", "1 year"],
    [41, 3128, "Front Office Assistant", 3, "10+2 or 10th pass", "Non-Engineering", "1 year"],
    [42, 3117, "Fire Technology and Industrial Safety Management", 3, "10+2 or 10th pass", "Non-Engineering", "1 year"],
    [43, 3052, "Wood Work Technician (Carpenter / General Carpenter)", 3, "10+2 or 8th pass", "Engineering", "1 year"],
    [44, 3058, "Mason (Building Constructor)", 3, "8th pass", "Engineering", "1 year"],
    [45, 3013, "Mechanic Auto Body Repair", 3, "10+2 or 10th pass (with Science subjects) or equivalent", "Engineering", "1 year"],
    [46, 3012, "Mechanic Auto Body Painting", 3, "10+2 or 10th pass", "Engineering", "1 year"],
    [47, 3010, "Driver cum Mechanic (Light Motor Vehicle)", 3, "8th pass (18 years old)", "Non-Engineering", "6 months"],
    [48, 3024, "Additive Manufacturing Technician (3D Printing)", 3, "10+2 or 10th pass (with Science subjects)", "Engineering", "1 year"],
    [49, 3029, "Work Technical Draftsman", 4, "Engineering", "Engineering", "2 years"],
    [50, 3053, "Civil Engineering Assistant", 4, "Engineering", "Engineering", "2 years"],
    [51, 3068, "IoT Technician (Smart Agriculture)", 3, "10+2 or 10th pass (with Science subjects)", "Non-Engineering", "1 year"],
    [52, 3069, "IoT Technician (Smart City)", 3, "Non-Engineering", "1 year"],
    [53, 3070, "IoT Technician (Smart Healthcare)", 3, "Non-Engineering", "1 year"],
    [54, 3018, "Mechanic Two and Three Wheeler", 3, "Engineering", "1 year"],
    [55, 3001, "Remotely Piloted Aircraft - Drone Pilot", 3, "10th pass (with Science subjects) (18 years old)", "Non-Engineering", "6 months"],
    [56, 3071, "Smart Phone Technician cum App Tester", 3, "10th pass", "Non-Engineering", "6 months"],
    [57, 3073, "Solar Technician (Electrical)", 3, "10+2 or 10th pass (with Science subjects)", "Engineering", "1 year"],
    [58, 3137, "Technician Mechatronics", 4, "Engineering", "Engineering", "2 years"],
    [59, 3088, "Technician Medical Electronics", 4, "Engineering", "Engineering", "2 years"],
    [60, 3042, "Welder (Fabrication & Fitting)", 3, "8th pass", "Engineering", "1 year"],
    [61, 3043, "Welder (GMAW & GTAW)", 3, "8th pass", "Engineering", "1 year"],
    [62, 3046, "Welder (Welding & Inspection)", 3, "10+2 or 8th pass (with Science subjects)", "Engineering", "1 year"],
    [63, 3119, "Health Safety and Environment", 3, "10+2 or 10th pass", "Non-Engineering", "1 year"],
    [64, 3087, "Old Age Care Assistant", 3, "10+2 or 10th pass", "Non-Engineering", "1 year"],
    [65, 3132, "Housekeeper", 3, "Non-Engineering", "1 year"],
    [66, 3118, "Fireman", 3, "Non-Engineering", "6 months"],
    [67, 3131, "Hospital Housekeeping", 3, "Non-Engineering", "1 year"],
    [68, 3138, "Data Entry Operator", 3, "Non-Engineering", "6 months"],
    [69, 3005, "Computer-Aided Embroidery and Design Training", 4, "Non-Engineering", "1 year"],
    [70, 3148, "Advanced CNC Machining Technician", 4, "Class X pass, enrolled for Class XII through NIOS, or ITI with Class X", "Engineering", "2 years"],
    [71, 3149, "Mechanic Electrical Vehicle", 4, "Class X pass, enrolled for Class XII through NIOS, or ITI with Class X", "Engineering", "2 years"],
    [72, 30141, "Mechanic Auto Electrical and Electronics", 3, "10+2 or 10th pass (with Science subjects)", "Engineering", "1 year"],
    [73, 30831, "Radiology Technician", 4, "10+2 or 10th pass (with Science subjects)", "Non-Engineering", "2 years"],
    [74, 30611, "Allied Educator", 3, "10+2 or 10th pass", "Non-Engineering", "1 year"],
    [101, 3167, "Advanced Industrial Sub-Fireman Officer", "10+2 or 10th pass", "Non-Engineering", "6 months"],
    [102, 3179, "Certificate Course in Systemware Technology Networking and Administration", "Engineering", "1 year"],
    [103, 3182, "Certificate Course in Multimedia Technology and DTP", "10+2 or 10th pass", "Non-Engineering", "1 year"],
    [104, 3193, "Certificate Course in Library and Information Science", "10+2 or 10th pass", "Non-Engineering", "6 months"],
    [105, 3177, "Certificate Course in E-Commerce", "Non-Engineering", "1 year"],
    [106, 3178, "Certificate Course in Software Programming", "Non-Engineering", "1 year"],
    [107, 3183, "Certificate Course in Web Design", "Non-Engineering", "1 year"],
    [108, 3162, "Certificate Course in Machinery Technology", "10+2 or 10th pass (with Science subjects)", "Engineering", "2 years"],
    [109, 3170, "Fireman", "Engineering", "1 year"],
    [110, 3199, "Domestic Appliance Repairer", "10+2 or 10th pass", "Non-Engineering", "1 year"],
    [111, 3164, "Man-Made Fiber Technology", "10+2 or 10th pass", "Engineering", "2 years"],
    [112, 3165, "Man-Made Yarn Processing Technology", "10+2 or 10th pass", "Engineering", "2 years"],
    [113, 3152, "Offset Printer and Packaging", "Non-Engineering", "1 year"],
    [114, 3194, "Stenographer cum Computer Operator (English)", "10+2 or 10th pass", "Non-Engineering", "1 year"],
    [115, 3185, "Stenographer cum Computer Operator (Gujarati)", "10+2 or 10th pass", "Non-Engineering", "1 year"],
    [116, 3181, "Stenography (Gujarati)", "10+2 or 10th pass", "Non-Engineering", "1 year"],
    [117, 3176, "Telephone Mobile Phone Repairing", "10+2 or 10th pass", "Engineering", "6 months"],
    [118, 3156, "Motor Rewinding/Coil Winder", "10+2 or 7th pass", "Engineering", "1 year"],
    [119, 3200, "Construction Technician", "10+2 or 8th pass", "Non-Engineering", "1 year"],
    [120, 3158, "General Mechanic", "10+2 or 7th pass", "Engineering", "2 years"],
    [121, 3174, "Software Programming and Testing Assistant", "10+2 or 10th pass", "Engineering", "2 years"],
    [122, 3150, "Marine Engineering Technician", "10+2 or 8th pass", "Engineering", "1 year"],
    [123, 3160, "Men's and Women's Garment Making", "10+2 or 7th pass", "Non-Engineering", "1 year"],
    [124, 3151, "Offset Printing and Book Binding", "10+2 or 8th pass", "Non-Engineering", "1 year"],
    [125, 3197, "Plumbing Assistant", "Engineering", "1 year"],
    [126, 3189, "Two Wheeler Auto Repairer", "Engineering", "1 year"],
]


data = [

]

# %%
import json

# Define the keys
keys = ["No.", "Trade Code", "Trade Name", "NSQF Level", "Minimum Educational Qualification", "Type", "Duration"]

# Data provided

# Create a list of dictionaries with the corresponding keys
data_dicts = [dict(zip(keys, item)) for item in data]

# Save to a JSON file
file_path = "trade_data.json"
with open(file_path, 'w') as json_file:
    json.dump(data_dicts, json_file, indent=4)

print(f"Data saved to {file_path}")
# Out:
# Data saved to trade_data.json

# %%
file_path = 'trades_data.json'

# Writing JSON data to a file
with open(file_path, 'w') as json_file:
    json.dump(json_data, json_file, indent=4)

# %%
import json

# Data to be saved



# Save data to a JSON file
with open('trade_data.json', 'w') as json_file:
    json.dump(data, json_file, indent=4)

print("Data saved to trade_data.json")
# Out:
# Data saved to trade_data.json
